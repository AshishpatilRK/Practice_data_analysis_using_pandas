# %%
# import libraries
import pandas as pd   # for analysis of data
import numpy as np     # for numerical operations
import seaborn as sns  # for visualization

# %%
import warnings    
warnings.filterwarnings("ignore")     # import warnings libraries  to ignore warning

# %%
covid19 = pd.read_csv(r"C:\Users\ashis\Downloads\covid_19_data.csv")   # read csv file using pandas

# %%
covid19.shape  #  shows rows and columns
# Out:
# (321, 6)

# %%
covid19.count()    # show count in variables
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
covid19.isnull().sum()    # show number of missing values in data
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
sns.heatmap(covid19.isnull())   # show number of missing values in data using heatmap
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q1. Show number of confirmed ,deaths and recovered cases in each column

# %%
covid19.groupby('Region').sum()   # here groupby Region then sum
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
covid19.groupby('Region').sum().head()   # show to top 5 rows
# Out:
#              Confirmed  Deaths  Recovered
# Region
# Afghanistan       1939      60        252
# Albania            766      30        455
# Algeria           3848     444       1702
# Andorra            743      42        423
# Angola              27       2          7

# %%
covid19.groupby('Region')['Confirmed'].sum().sort_values(ascending = False) # sorting confirmed cases in descending
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
covid19.groupby('Region')['Confirmed'].sum().sort_values(ascending = False).head(10)  # show top 10 countries
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
covid19.groupby('Region')['Confirmed','Recovered'].sum()  # using  selecting columns
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %% [markdown]
# ### Q2. Remove all records where confirmed cases is less than 10

# %%
covid19 = covid19[~(covid19.Confirmed < 10)]      # here remove   all records where confirmed cases is less than 10

# %%
covid19.head(20)
# Out:
#          Date State                  Region  Confirmed  Deaths  Recovered
# 0   4/29/2020   NaN             Afghanistan       1939      60        252
# 1   4/29/2020   NaN                 Albania        766      30        455
# 2   4/29/2020   NaN                 Algeria       3848     444       1702
# 3   4/29/2020   NaN                 Andorra        743      42        423
# 4   4/29/2020   NaN                  Angola         27       2          7
# 5   4/29/2020   NaN     Antigua and Barbuda         24       3         11
# 6   4/29/2020   NaN               Argentina       4285     214       1192
# 7   4/29/2020   NaN                 Armenia       1932      30        900
# 8   4/29/2020   NaN                 Austria      15402     580      12779
# 9   4/29/2020   NaN              Azerbaijan       1766      23       1267
# 10  4/29/2020   NaN                 Bahamas         80      11         23
# 11  4/29/2020   NaN                 Bahrain       2921       8       1455
# ...

# %%
covid19.shape   # after  removing all records where confirmed cases is less than 10  get data shape
# Out:
# (304, 6)

# %% [markdown]
# ### Q3. In which region maximum  number of confirmed cases were recorded?

# %%
covid19 = pd.read_csv(r"C:\Users\ashis\Downloads\covid_19_data.csv")     # again read csv file

# %%
covid19.groupby('Region').Confirmed.sum().sort_values(ascending = False).head(1) # use sort in descending  to get maximum
# Out:
# Region
# US    1039909
# Name: Confirmed, dtype: int64

# %% [markdown]
# ### Q4. in which region, minimum number of deaths where recorded ?

# %%
covid19.groupby('Region').Deaths.sum().sort_values(ascending = True).head(50) # sort in ascending order
# Out:
# Region
# Laos                                0
# Mongolia                            0
# Mozambique                          0
# Cambodia                            0
# Fiji                                0
# Namibia                             0
# Nepal                               0
# Madagascar                          0
# Macau                               0
# Papua New Guinea                    0
# Rwanda                              0
# Saint Kitts and Nevis               0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Saint Lucia                         0
# Holy See                            0
# Sao Tome and Principe               0
# Yemen                               0
# Western Sahara                      0
# Eritrea                             0
# Vietnam                             0
# Saint Vincent and the Grenadines    0
# Timor-Leste                         0
# ...

# %% [markdown]
# ### Q5. How many Confirmed, Deaths, Recovered cases were recorded from india till 29 April  2020?

# %%
covid19[covid19.Region == "India"]      # filtering with india
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %% [markdown]
# ### Q6. Sort the entire data wrt Confirmed cases in ascending order

# %%
covid19.sort_values(by = ['Confirmed'], ascending = True).head(50)    # sort in ascending order
# Out:
#           Date                             State  \
# 285  4/29/2020                         Recovered
# 284  4/29/2020                         Recovered
# 203  4/29/2020      Diamond Princess cruise ship
# 305  4/29/2020                             Tibet
# 289  4/29/2020         Saint Pierre and Miquelon
# 184  4/29/2020                          Anguilla
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba
# 272  4/29/2020             Northwest Territories
# 288  4/29/2020                  Saint Barthelemy
# 178  4/29/2020                               NaN
# 194  4/29/2020            British Virgin Islands
# 177  4/29/2020                               NaN
# 18   4/29/2020                               NaN
# 126  4/29/2020                               NaN
# 140  4/29/2020                               NaN
# 105  4/29/2020                               NaN
# 98   4/29/2020                               NaN
# 156  4/29/2020                               NaN
# ...

# %% [markdown]
# ### Q7. Sort the entire data wrt Recoverd cases in descending order

# %%
covid19.sort_values( by = ['Recovered'], ascending = False).head(50)  # sort in descending order
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 285  4/29/2020        Recovered                    US          0       0
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 284  4/29/2020        Recovered                Canada          0       0
# 78   4/29/2020              NaN               Ireland      20253    1190
# ...
